# %% [markdown]
# ## linear Regression

# %%
hours = [[2],[3],[4],[5],[6],[7]] #x-variable
marks = [43,50,57,68,76,81] # y-variable

# %%
import pandas as pd
df= pd.DataFrame(hours,marks)

# %%
df.to_csv('marks.csv')

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(hours,marks)

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.regplot(x=hours, y=marks, color='red')
# Out:
# <Axes: >

# %%
import sklearn.linear_model

# %%
# Algorithm
regressor = sklearn.linear_model.LinearRegression()

# %%
regressor
# Out:
# LinearRegression()

# %%
# Training the algorithm
regressor.fit(hours, marks)
# Out:
# LinearRegression()

# %%
a = [9,3,5,6]
a[1]
# Out:
# 3

# %%
a = [[9,3,5,6],[4,5,6,3]]
a[1]
# Out:
# [4, 5, 6, 3]

# %%
a[0][1]
# Out:
# 3

# %%
import pickle as pkl

# %%
pkl.dump(regressor, open('a.pkl','wb'))
hours_test = [[8]]

# %%
marks_pred = regressor.predict(hours_test)

# %%
marks_pred
# Out:
# array([90.4])

# %%
df1 = pd.DataFrame({'original': marks_pred},{'pridicted':hours_test})

# %%
df1
# Out:
#            original
# pridicted      90.4

# %%
regressor.predict([[8.5]])
# Out:
# array([94.38571429])
